# %%
import numpy as np
import sub_func
from sub_func import abs_dis, ideal_cor, cor_func
import math
import time
from itertools import combinations
from random import randrange

# %% [markdown]
# 1NN: 0.707 | 2NN: 1 | 3NN: 1.225 | 4NN: 1.414 | 5NN: 1.581 | 6NN: 1.732
#
# l1: 0 | l2: 0.57735027 | l3: 1.15470054 | l4: 1.73205081 | l5: 2.30940108 | 2.88675135

# %%
dis_list = dis_list

# %%
#*ideal_cor
#*cor_func
ind_1nn, ind_2nn, ind_3nn, ind_4nn, ind_5nn, ind_6nn = [], [], [], [], [], []
ind_raw = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_raw.npy')
for i, j in combinations(range(216), 2):
    a1, a2 = ind_raw[i], ind_raw[j]
    if abs_dis(a1, a2, 0.707) < 0.001:
        ind_1nn.append([i, j])
    if abs_dis(a1, a2, 1) < 0.001:
        ind_2nn.append([i, j])
    if abs_dis(a1, a2, 1.225) < 0.001:
        ind_3nn.append([i, j])
    if abs_dis(a1, a2, 1.414) < 0.001:
        ind_4nn.append([i, j])
    if abs_dis(a1, a2, 1.581) < 0.001:
        ind_5nn.append([i, j])
    if abs_dis(a1, a2, 1.732) < 0.001:
        ind_6nn.append([i, j])

np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn.npy', ind_1nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn.npy', ind_2nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn.npy', ind_3nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn.npy', ind_4nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_5nn.npy', ind_5nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_6nn.npy', ind_6nn)

# %%
ind_layer_345, ind_layer_34, ind_layer_45 = [], [], []
for i in range(216):
    a_ = ind_raw[i][2]
    if a_ == math.sqrt(1/3)*2 or a_ == math.sqrt(1/3)*3 or a_ == math.sqrt(1/3)*4:
        ind_layer_345.append(i)

    if a_ == math.sqrt(1/3)*2 or a_ == math.sqrt(1/3)*3:
        ind_layer_34.append(i)

    if a_ == math.sqrt(1/3)*3 or a_ == math.sqrt(1/3)*4:
        ind_layer_45.append(i)

np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_l_345.npy', ind_layer_345)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_l_34.npy', ind_layer_34)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_l_45.npy', ind_layer_45)

# %%
ind_raw_345 = np.array([ind_raw[i] for i in ind_layer_345])
ind_raw_34 = np.array([ind_raw[i] for i in ind_layer_34])
ind_raw_45 = np.array([ind_raw[i] for i in ind_layer_45])

#*layer345
ind_1nn, ind_2nn, ind_3nn, ind_4nn = [], [], [], []
for i, j in combinations(ind_layer_345, 2):
    a1, a2 = ind_raw[i], ind_raw[j]
    if abs_dis(a1, a2, 0.707) < 0.001:
        ind_1nn.append([i, j])
    if abs_dis(a1, a2, 1) < 0.001:
        ind_2nn.append([i, j])
    if abs_dis(a1, a2, 1.225) < 0.001:
        ind_3nn.append([i, j])
    if abs_dis(a1, a2, 1.414) < 0.001:
        ind_4nn.append([i, j])

np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn_345.npy', ind_1nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn_345.npy', ind_2nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn_345.npy', ind_3nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn_345.npy', ind_4nn)

#*layer34
ind_1nn, ind_2nn, ind_3nn, ind_4nn = [], [], [], []
for i, j in combinations(ind_layer_34, 2):
    a1, a2 = ind_raw[i], ind_raw[j]
    if abs_dis(a1, a2, 0.707) < 0.001:
        ind_1nn.append([i, j])
    if abs_dis(a1, a2, 1) < 0.001:
        ind_2nn.append([i, j])
    if abs_dis(a1, a2, 1.225) < 0.001:
        ind_3nn.append([i, j])
    if abs_dis(a1, a2, 1.414) < 0.001:
        ind_4nn.append([i, j])

np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn_34.npy', ind_1nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn_34.npy', ind_2nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn_34.npy', ind_3nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn_34.npy', ind_4nn)

#*layer45
ind_1nn, ind_2nn, ind_3nn, ind_4nn = [], [], [], []
for i, j in combinations(ind_layer_45, 2):
    a1, a2 = ind_raw[i], ind_raw[j]
    if abs_dis(a1, a2, 0.707) < 0.001:
        ind_1nn.append([i, j])
    if abs_dis(a1, a2, 1) < 0.001:
        ind_2nn.append([i, j])
    if abs_dis(a1, a2, 1.225) < 0.001:
        ind_3nn.append([i, j])
    if abs_dis(a1, a2, 1.414) < 0.001:
        ind_4nn.append([i, j])

np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn_45.npy', ind_1nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn_45.npy', ind_2nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn_45.npy', ind_3nn)
np.save('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn_45.npy', ind_4nn)

# %%
ind_1nn = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn.npy')
ind_2nn = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn.npy')
ind_3nn = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn.npy')
ind_4nn = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn.npy')

ind_1nn_345 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn_345.npy')
ind_2nn_345 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn_345.npy')
ind_3nn_345 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn_345.npy')
ind_4nn_345 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn_345.npy')

ind_1nn_34 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn_34.npy')
ind_2nn_34 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn_34.npy')
ind_3nn_34 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn_34.npy')
ind_4nn_34 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn_34.npy')

ind_1nn_45 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_1nn_45.npy')
ind_2nn_45 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_2nn_45.npy')
ind_3nn_45 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_3nn_45.npy')
ind_4nn_45 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_4nn_45.npy')

ind_layer_345 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_l_345.npy')
ind_layer_34 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_l_34.npy')
ind_layer_45 = np.load('C:/Users/yaoho/OneDrive - Kyoto University/Project/GSFE/fcc_256/ind_l_45.npy')

#######################################
class genetic:
    def __init__(self, cr_, mn_, co_, ni_,
                ind_1nn, ind_2nn, ind_3nn, ind_4nn,
                ind_1nn_345, ind_2nn_345, ind_3nn_345, ind_4nn_345,
                ind_1nn_34, ind_2nn_34, ind_3nn_34, ind_4nn_34,
                ind_1nn_45, ind_2nn_45, ind_3nn_45, ind_4nn_45,
                ind_layer_345, ind_layer_34, ind_layer_45,
                state):
        
        assert cr_+mn_+co_+ni_ == 1, 'Make sure the content summing to 1'
        self.ind_1nn, self.ind_2nn, self.ind_3nn, self.ind_4nn = ind_1nn, ind_2nn, ind_3nn, ind_4nn
        self.ind_1nn_345, self.ind_2nn_345, self.ind_3nn_345, self.ind_4nn_345 = ind_1nn_345, ind_2nn_345, ind_3nn_345, ind_4nn_345
        self.ind_1nn_34, self.ind_2nn_34, self.ind_3nn_34, self.ind_4nn_34 = ind_1nn_34, ind_2nn_34, ind_3nn_34, ind_4nn_34
        self.ind_1nn_45, self.ind_2nn_45, self.ind_3nn_45, self.ind_4nn_45 = ind_1nn_45, ind_2nn_45, ind_3nn_45, ind_4nn_45

        self.ideal_1 = ideal_cor(cr_, mn_, co_, ind_1nn)
        self.ideal_2 = ideal_cor(cr_, mn_, co_, ind_2nn)
        self.ideal_3 = ideal_cor(cr_, mn_, co_, ind_3nn)
        self.ideal_4 = ideal_cor(cr_, mn_, co_, ind_4nn)

        self.ideal_1_345 = ideal_cor(cr_, mn_, co_, ind_1nn_345)
        self.ideal_2_345 = ideal_cor(cr_, mn_, co_, ind_2nn_345)
        self.ideal_3_345 = ideal_cor(cr_, mn_, co_, ind_3nn_345)
        self.ideal_4_345 = ideal_cor(cr_, mn_, co_, ind_4nn_345)

        self.ideal_1_34 = ideal_cor(cr_, mn_, co_, ind_1nn_34)
        self.ideal_2_34 = ideal_cor(cr_, mn_, co_, ind_2nn_34)
        self.ideal_3_34 = ideal_cor(cr_, mn_, co_, ind_3nn_34)
        self.ideal_4_34 = ideal_cor(cr_, mn_, co_, ind_4nn_34)

        self.ideal_1_45 = ideal_cor(cr_, mn_, co_, ind_1nn_45)
        self.ideal_2_45 = ideal_cor(cr_, mn_, co_, ind_2nn_45)
        self.ideal_3_45 = ideal_cor(cr_, mn_, co_, ind_3nn_45)
        self.ideal_4_45 = ideal_cor(cr_, mn_, co_, ind_4nn_45)

        self.ind_345, self.ind_34, self.ind_45 = ind_layer_345, ind_layer_34, ind_layer_45
        self.state = state

    def swap_step(self, state, action):
        a1, a2 = action
        state[a1], state[a2] = state[a2], state[a1]
        return state

    def mutation_raw(self, mode, state):
        epsilon_ = np.random.rand()
        if epsilon_ < 0.6:
            repeat_time = np.random.randint(2, 8)
        elif epsilon_ >= 0.6:
            repeat_time = np.random.randint(6, 12)

        if mode == 'whole':
            for time_ in range(repeat_time):
                action = np.array([randrange(216), randrange(216)])
                state = self.swap_step(state, action)

        elif mode == 'duo34':
            for time_ in range(repeat_time):
                action = np.array([np.random.choie(self.ind_34), np.random.choice(self.ind_34)])
                state = self.swap_step(state, action)
        
        elif mode == 'duo45':
            for time_ in range(repeat_time):
                action = np.array([np.random.choie(self.ind_45), np.random.choice(self.ind_45)])
                state = self.swap_step(state, action)

        elif mode == 'tri':
            for time_ in range(repeat_time):
                action = np.array([np.random.choie(self.ind_345), np.random.choice(self.ind_345)])
                state = self.swap_step(state, action)

        return state
            
    def mut_whole(self, state):
        return self.mutation_raw('whole', state)

    def mut_34(self, state):
        return self.mutation_raw('duo34', state)

    def mut_45(self, state):
        return self.mutation_raw('duo45', state)

    def mut_345(self, state):
        return self.mutation_raw('tri', state)

    def Fitness(self, state):
        state_345 = np.array([state[i] for i in self.ind_345])
        state_34 = np.array([state[i] for i in self.ind_34])
        state_45 = np.array([state[i] for i in self.ind_45])
        
        cor_func_1 = cor_func(self.ind_1nn, state,)
        cor_func_2 = cor_func(self.ind_2nn, state,)
        cor_func_3 = cor_func(self.ind_3nn, state,)
        cor_func_4 = cor_func(self.ind_4nn, state,)

        res_1 = np.abs(cor_func_1 - self.ideal_1)
        res_2 = np.abs(cor_func_2 - self.ideal_2)
        res_3 = np.abs(cor_func_3 - self.ideal_3)
        res_4 = np.abs(cor_func_4 - self.ideal_4)

        res_whole = np.concatenate([res_1, res_2, res_3, res_4])

        cor_func_1_345 = cor_func(self.ind_1nn_345, state,)
        cor_func_2_345 = cor_func(self.ind_2nn_345, state,)
        cor_func_3_345 = cor_func(self.ind_3nn_345, state,)
        cor_func_4_345 = cor_func(self.ind_4nn_345, state,)

        res_1_345 = np.abs(cor_func_1_345 - self.ideal_1_345)
        res_2_345 = np.abs(cor_func_2_345 - self.ideal_2_345)
        res_3_345 = np.abs(cor_func_3_345 - self.ideal_3_345)
        res_4_345 = np.abs(cor_func_4_345 - self.ideal_4_345)

        res_345 = np.concatenate([res_1_345, res_2_345, res_3_345, res_4_345])

        cor_func_1_34 = cor_func(self.ind_1nn_34, state,)
        cor_func_2_34 = cor_func(self.ind_2nn_34, state,)
        cor_func_3_34 = cor_func(self.ind_3nn_34, state,)
        cor_func_4_34 = cor_func(self.ind_4nn_34, state,)

        res_1_34 = np.abs(cor_func_1_34 - self.ideal_1_34)
        res_2_34 = np.abs(cor_func_2_34 - self.ideal_2_34)
        res_3_34 = np.abs(cor_func_3_34 - self.ideal_3_34)
        res_4_34 = np.abs(cor_func_4_34 - self.ideal_4_34)

        res_34 = np.concatenate([res_1_34, res_2_34, res_3_34, res_4_34])

        cor_func_1_45 = cor_func(self.ind_1nn_45, state,)
        cor_func_2_45 = cor_func(self.ind_2nn_45, state,)
        cor_func_3_45 = cor_func(self.ind_3nn_45, state,)
        cor_func_4_45 = cor_func(self.ind_4nn_45, state,)

        res_1_45 = np.abs(cor_func_1_45 - self.ideal_1_45)
        res_2_45 = np.abs(cor_func_2_45 - self.ideal_2_45)
        res_3_45 = np.abs(cor_func_3_45 - self.ideal_3_45)
        res_4_45 = np.abs(cor_func_4_45 - self.ideal_4_45)

        res_45 = np.concatenate([res_1_45, res_2_45, res_3_45, res_4_45])

        p_whole, p_345, p_34, p_45 = 1, 2, 5, 5
        res_overall = np.concatenate([res_whole*p_whole, res_345*p_345, res_34*p_34, res_45*p_45])
        fitness = np.linalg.norm(res_overall)
        fitness_345 = np.linalg.norm(res_345)
        fitness_34, fitness_45 = np.linalg.norm(res_34), np.linalg.norm(res_45)  

        return fitness, fitness_345, fitness_34, fitness_45    
    
    def chosen_ind_list(self, fitness, repeat_time):
        
        p_fit = np.exp(fitness) / np.sum(np.exp(fitness))
        for i in range(repeat_time):
            chosen_ind = np.random.choice(fitness, p=p_fit)

        return chosen_ind

# %%
fitness = np.array([1,2,3,4,5])
fitness = -fitness
p_fit = np.exp(fitness) / np.sum(np.exp(fitness))
p_fit
# Out:
# array([0.63640865, 0.23412166, 0.08612854, 0.03168492, 0.01165623])
